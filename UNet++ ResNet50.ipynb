# %% [markdown]
# # Bee segmentation, removal, and timelapse algorithms

# %% [markdown]
# ## Imports required for the methods below
# The second code chunk is the necessary imports for the rest of the code. The first code chunk may be necessary if the python kernel keeps crashing, but otherwise can be ignored.

# %%
#kernel kept crashing, was suggested to use this to fix -Emily
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# Importing necessary libraries
import os
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch.nn as nn
import segmentation_models_pytorch as smp
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR

# import matplotlib.image as mpimg
# import torch.optim as optim
# import sys
# from tqdm import tqdm as tqdm

# %% [markdown]
# ## Import data to train the model
# Data has been annotated to train the data on where to detect bees in an image.
#
# We would recomend duplicating the GitHub repository on your personal computer so that you have access to all the files. Since the GitHub repository is private, DATA_DIR will need to be changed to correspond with your personal computer.

# %%
# Prepare the Data
DATA_DIR = "C:\\Users\\Emily\\OneDrive\\Desktop\\Github\\AU_Biol\\Data" #TODO: Change to local image folder
x_train_dir = os.path.join(DATA_DIR, 'X_train') #16 images
y_train_dir = os.path.join(DATA_DIR, 'y_train')
x_valid_dir = os.path.join(DATA_DIR, 'X_val') #2 images
y_valid_dir = os.path.join(DATA_DIR, 'y_val')
x_test_dir = os.path.join(DATA_DIR, 'X_test') #2 images
y_test_dir = os.path.join(DATA_DIR, 'y_test')

class SegmentationDataset(Dataset):
    def __init__(self, imgs_dir, masks_dir, transform=None):
        self.imgs_dir = imgs_dir
        self.masks_dir = masks_dir
        self.transform = transform
        
        self.ids = os.listdir(imgs_dir)
        
    def __len__(self):
        return len(self.ids)
    
    def __getitem__(self, idx):
        img_path = os.path.join(self.imgs_dir, self.ids[idx])
        mask_path = os.path.join(self.masks_dir, self.ids[idx].replace(".jpg", ".png"))
        
        image = cv2.imread(img_path, cv2.IMREAD_UNCHANGED).astype(np.float32)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        mask = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED).astype(np.float32)
        mask = (mask > 127).astype(np.float32)  # Convert mask to binary 0 and 1
        
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask'][None]
            
        return image, mask

# Define transformations
# Training transformations with augmentations
train_transform = A.Compose([
    A.Resize(256, 256),
    A.RandomRotate90(),
    A.Flip(),
    A.Transpose(),
    A.OneOf([
        A.ElasticTransform(p=0.1),
        A.GridDistortion(p=0.1),
        A.OpticalDistortion(p=0.1)
    ], p=0.2),
    A.RandomBrightnessContrast(p=0.2),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# Validation and test transformations without augmentations
valid_transform = A.Compose([
    A.Resize(256, 256),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# Apply the transformations to the datasets
train_dataset = SegmentationDataset(x_train_dir, y_train_dir, train_transform)
valid_dataset = SegmentationDataset(x_valid_dir, y_valid_dir, valid_transform)
test_dataset = SegmentationDataset(x_test_dir, y_test_dir, valid_transform)

# %%
print(len(train_dataset))
# Out:
# 16

# %% [markdown]
# ### Set-up for the model

# %%
class DiceLoss(nn.Module):
    def __init__(self, eps=1e-7):
        super(DiceLoss, self).__init__()
        self.eps = eps
        
    def forward(self, logits, targets):
        # logits: predictions (after sigmoid or softmax)
        # targets: ground truth
        
        # Convert logits to binary predictions
        probs = torch.sigmoid(logits)
        
        # Flatten the tensors
        num = targets.size(0)
        m1 = probs.view(num, -1)
        m2 = targets.view(num, -1)
        
        intersection = (m1 * m2).sum()
        
        return 1 - (2. * intersection + self.eps) / (m1.sum() + m2.sum() + self.eps)

# %%
# Define the model and training specifics:

ENCODER = 'resnet50'
ENCODER_WEIGHTS = 'imagenet'
# ACTIVATION = 'sigmoid'
ACTIVATION = 'sigmoid'
DECODER = 'UnetPlusPlus' 

model = smp.UnetPlusPlus(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    in_channels=3, 
    classes=1, 
    activation=ACTIVATION
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.002)
criterion = nn.BCELoss()
#criterion = DiceLoss().to(device)




num_epochs = 100
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# ### Defining scoring metrics for the model (accuracy, IOU, etc.)

# %%
# Implement the metrics:
def iou_score(output, target):
    smooth = 1e-5
    # Remove single-dimension entries from the shape of an array.
    output = torch.squeeze(output)
    target = torch.squeeze(target)
    intersection = (output & target).float().sum()
    union = (output | target).float().sum()
    iou = (intersection + smooth) / (union + smooth)
    return iou.item()


def get_metrics(output, target):
    output = output.squeeze().detach().cpu().numpy()
    target = target.squeeze().detach().cpu().numpy()

    output = (output > 0.5).astype(np.uint8)
    target = target.astype(np.uint8)
    
    iou = iou_score(torch.tensor(output), torch.tensor(target))
    accuracy = accuracy_score(target.ravel(), output.ravel())
    recall = recall_score(target.ravel(), output.ravel())
    precision = precision_score(target.ravel(), output.ravel())
    f_score = f1_score(target.ravel(), output.ravel())
    
    return iou, accuracy, recall, precision, f_score

# %% [markdown]
# ## Training of the model
# The model_path will need to be updated for your personal computer. Any folder will suffice, but the path will need to be named. We used 'UNETPLUSPLUS_model.pth', but any name that ends with .pth will work. Note: this is a large file so it is not able to be uploaded to the github repository.

# %%
#  Train the model:


# For early stopping based on accuracy
best_accuracy = 0.0
epochs_without_improvement = 0

model_path = "C:\\Users\\Emily\\OneDrive - Auburn University\\Capstone Work\\UNETPLUSPLUS_model.pth" #TODO: change to local folder

# For decreasing the learning rate after 3 epochs
scheduler = StepLR(optimizer, step_size=6, gamma=0.4)

for epoch in range(num_epochs):
    model.train()
    
    # Training phase
    train_loss = 0.0
    for images, masks in train_loader:
        images, masks = images.to(device), masks.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        
        loss = criterion(outputs, masks)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    train_loss /= len(train_loader)

    # Evaluation phase
    model.eval()
    valid_loss, total_iou, total_acc, total_recall, total_precision, total_fscore = 0, 0, 0, 0, 0,0
    with torch.no_grad():
        for images, masks in valid_loader:
            images, masks = images.to(device), masks.to(device)
            outputs = model(images)
            
            loss = criterion(outputs, masks)
            valid_loss += loss.item()

            iou, accuracy, recall, precision, f_score = get_metrics(outputs, masks)
            
            total_iou += iou
            total_acc += accuracy
            total_recall += recall
            total_precision += precision
            total_fscore += f_score

    valid_loss /= len(valid_loader)
    avg_iou = total_iou / len(valid_loader)
    avg_acc = total_acc / len(valid_loader)

    print(f"Epoch: {epoch+1}, Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}, IoU: {avg_iou:.4f}, Acc: {avg_acc:.4f}, Recall: {total_recall/len(valid_loader):.4f}, Precision: {total_precision/len(valid_loader):.4f}, F1: {total_fscore/len(valid_loader):.4f}")

    # Check if accuracy improved
    if avg_acc > best_accuracy:
        best_accuracy = avg_acc
        torch.save(model.state_dict(), model_path)
        print("Best model saved with accuracy:", best_accuracy)
        epochs_without_improvement = 0
        
        
    else:
        epochs_without_improvement += 1

    # Early stopping based on accuracy
    if epochs_without_improvement == 50:
        print("Early stopping triggered after 50 epochs without accuracy improvement.")
        break

    # Step the scheduler (decrease the learning rate after each epoch)
    scheduler.step()
# Out:
# Epoch: 1, Train Loss: 0.7301, Valid Loss: 36.5760, IoU: 0.0130, Acc: 0.5965, Recall: 0.0134, Precision: 0.2840, F1: 0.0256
# Best model saved with accuracy: 0.5965499877929688
# Epoch: 2, Train Loss: 0.6764, Valid Loss: 59.2468, IoU: 0.3977, Acc: 0.4070, Recall: 0.9905, Precision: 0.3992, F1: 0.5691
# Epoch: 3, Train Loss: 0.5964, Valid Loss: 39.4036, IoU: 0.0144, Acc: 0.5963, Recall: 0.0149, Precision: 0.2920, F1: 0.0283
# Epoch: 4, Train Loss: 0.5552, Valid Loss: 37.8946, IoU: 0.0025, Acc: 0.6037, Recall: 0.0025, Precision: 0.3446, F1: 0.0051
# Best model saved with accuracy: 0.6037216186523438
# Epoch: 5, Train Loss: 0.5515, Valid Loss: 36.2318, IoU: 0.0003, Acc: 0.6046, Recall: 0.0003, Precision: 0.3684, F1: 0.0005
# Best model saved with accuracy: 0.60455322265625
# Epoch: 6, Train Loss: 0.4971, Valid Loss: 29.1477, IoU: 0.0010, Acc: 0.6020, Recall: 0.0010, Precision: 0.1153, F1: 0.0020
# Epoch: 7, Train Loss: 0.5681, Valid Loss: 1.1520, IoU: 0.3928, Acc: 0.7026, Recall: 0.4865, Precision: 0.6709, F1: 0.5640
# Best model saved with accuracy: 0.7026443481445312
# Epoch: 8, Train Loss: 0.4983, Valid Loss: 0.5239, IoU: 0.5671, Acc: 0.7650, Recall: 0.7787, Precision: 0.6760, F1: 0.7237
# Best model saved with accuracy: 0.7649612426757812
# Epoch: 9, Train Loss: 0.5020, Valid Loss: 0.4968, IoU: 0.5854, Acc: 0.7523, Recall: 0.8845, Precision: 0.6339, F1: 0.7385
# Epoch: 10, Train Loss: 0.4858, Valid Loss: 0.5441, IoU: 0.5846, Acc: 0.7376, Recall: 0.9339, Precision: 0.6098, F1: 0.7379
# Epoch: 11, Train Loss: 0.5702, Valid Loss: 0.5962, IoU: 0.5662, Acc: 0.7151, Recall: 0.9407, Precision: 0.5872, F1: 0.7231
# Epoch: 12, Train Loss: 0.5465, Valid Loss: 0.5625, IoU: 0.5657, Acc: 0.7132, Recall: 0.9447, Precision: 0.5851, F1: 0.7226
# Epoch: 13, Train Loss: 0.4987, Valid Loss: 0.4918, IoU: 0.5911, Acc: 0.7438, Recall: 0.9370, Precision: 0.6156, F1: 0.7430
# Epoch: 14, Train Loss: 0.4965, Valid Loss: 0.4413, IoU: 0.6175, Acc: 0.7727, Recall: 0.9281, Precision: 0.6485, F1: 0.7635
# Best model saved with accuracy: 0.7727203369140625
# Epoch: 15, Train Loss: 0.4552, Valid Loss: 0.4162, IoU: 0.6325, Acc: 0.7878, Recall: 0.9237, Precision: 0.6673, F1: 0.7749
# Best model saved with accuracy: 0.7877731323242188
# Epoch: 16, Train Loss: 0.4448, Valid Loss: 0.4084, IoU: 0.6371, Acc: 0.7926, Recall: 0.9209, Precision: 0.6740, F1: 0.7784
# Best model saved with accuracy: 0.7926483154296875
# Epoch: 17, Train Loss: 0.4890, Valid Loss: 0.4051, IoU: 0.6394, Acc: 0.7956, Recall: 0.9167, Precision: 0.6789, F1: 0.7801
# Best model saved with accuracy: 0.795623779296875
# Epoch: 18, Train Loss: 0.4304, Valid Loss: 0.4183, IoU: 0.6345, Acc: 0.7883, Recall: 0.9297, Precision: 0.6665, F1: 0.7764
# Epoch: 19, Train Loss: 0.4501, Valid Loss: 0.4205, IoU: 0.6330, Acc: 0.7864, Recall: 0.9319, Precision: 0.6637, F1: 0.7753
# Epoch: 20, Train Loss: 0.4408, Valid Loss: 0.4190, IoU: 0.6338, Acc: 0.7876, Recall: 0.9301, Precision: 0.6655, F1: 0.7759
# Epoch: 21, Train Loss: 0.4151, Valid Loss: 0.4226, IoU: 0.6319, Acc: 0.7854, Recall: 0.9319, Precision: 0.6626, F1: 0.7745
# Epoch: 22, Train Loss: 0.4640, Valid Loss: 0.4218, IoU: 0.6329, Acc: 0.7870, Recall: 0.9288, Precision: 0.6651, F1: 0.7751
# Epoch: 23, Train Loss: 0.4237, Valid Loss: 0.4214, IoU: 0.6340, Acc: 0.7888, Recall: 0.9255, Precision: 0.6681, F1: 0.7760
# Epoch: 24, Train Loss: 0.4757, Valid Loss: 0.4166, IoU: 0.6362, Acc: 0.7920, Recall: 0.9200, Precision: 0.6734, F1: 0.7776
# Epoch: 25, Train Loss: 0.4469, Valid Loss: 0.4099, IoU: 0.6396, Acc: 0.7962, Recall: 0.9148, Precision: 0.6801, F1: 0.7802
# Best model saved with accuracy: 0.7962188720703125
# Epoch: 26, Train Loss: 0.4856, Valid Loss: 0.3940, IoU: 0.6488, Acc: 0.8074, Recall: 0.9002, Precision: 0.6991, F1: 0.7870
# Best model saved with accuracy: 0.8073501586914062
# Epoch: 27, Train Loss: 0.4318, Valid Loss: 0.3889, IoU: 0.6523, Acc: 0.8107, Recall: 0.8980, Precision: 0.7045, F1: 0.7896
# Best model saved with accuracy: 0.8107452392578125
# Epoch: 28, Train Loss: 0.4210, Valid Loss: 0.3860, IoU: 0.6541, Acc: 0.8121, Recall: 0.8984, Precision: 0.7063, F1: 0.7909
# Best model saved with accuracy: 0.8121337890625
# Epoch: 29, Train Loss: 0.4510, Valid Loss: 0.3795, IoU: 0.6580, Acc: 0.8164, Recall: 0.8933, Precision: 0.7141, F1: 0.7937
# Best model saved with accuracy: 0.8164443969726562
# Epoch: 30, Train Loss: 0.4840, Valid Loss: 0.3766, IoU: 0.6598, Acc: 0.8181, Recall: 0.8923, Precision: 0.7169, F1: 0.7951
# Best model saved with accuracy: 0.8181228637695312
# Epoch: 31, Train Loss: 0.4044, Valid Loss: 0.3757, IoU: 0.6607, Acc: 0.8184, Recall: 0.8943, Precision: 0.7166, F1: 0.7957
# Best model saved with accuracy: 0.8184127807617188
# Epoch: 32, Train Loss: 0.4797, Valid Loss: 0.3728, IoU: 0.6623, Acc: 0.8205, Recall: 0.8902, Precision: 0.7212, F1: 0.7968
# Best model saved with accuracy: 0.8205184936523438
# Epoch: 33, Train Loss: 0.4911, Valid Loss: 0.3675, IoU: 0.6648, Acc: 0.8237, Recall: 0.8844, Precision: 0.7281, F1: 0.7987
# Best model saved with accuracy: 0.82373046875
# Epoch: 34, Train Loss: 0.4944, Valid Loss: 0.3694, IoU: 0.6651, Acc: 0.8227, Recall: 0.8903, Precision: 0.7244, F1: 0.7988
# Epoch: 35, Train Loss: 0.4364, Valid Loss: 0.3691, IoU: 0.6653, Acc: 0.8227, Recall: 0.8910, Precision: 0.7242, F1: 0.7990
# Epoch: 36, Train Loss: 0.4196, Valid Loss: 0.3703, IoU: 0.6644, Acc: 0.8214, Recall: 0.8942, Precision: 0.7211, F1: 0.7984
# Epoch: 37, Train Loss: 0.4416, Valid Loss: 0.3734, IoU: 0.6629, Acc: 0.8193, Recall: 0.8985, Precision: 0.7165, F1: 0.7973
# Epoch: 38, Train Loss: 0.4470, Valid Loss: 0.3692, IoU: 0.6658, Acc: 0.8229, Recall: 0.8921, Precision: 0.7241, F1: 0.7993
# Epoch: 39, Train Loss: 0.4541, Valid Loss: 0.3670, IoU: 0.6663, Acc: 0.8240, Recall: 0.8887, Precision: 0.7269, F1: 0.7997
# Best model saved with accuracy: 0.8240127563476562
# Epoch: 40, Train Loss: 0.4456, Valid Loss: 0.3689, IoU: 0.6660, Acc: 0.8229, Recall: 0.8934, Precision: 0.7235, F1: 0.7996
# Epoch: 41, Train Loss: 0.4134, Valid Loss: 0.3695, IoU: 0.6646, Acc: 0.8218, Recall: 0.8934, Precision: 0.7219, F1: 0.7985
# Epoch: 42, Train Loss: 0.4231, Valid Loss: 0.3676, IoU: 0.6650, Acc: 0.8231, Recall: 0.8880, Precision: 0.7259, F1: 0.7988
# Epoch: 43, Train Loss: 0.4816, Valid Loss: 0.3696, IoU: 0.6659, Acc: 0.8228, Recall: 0.8933, Precision: 0.7235, F1: 0.7995
# Epoch: 44, Train Loss: 0.4215, Valid Loss: 0.3715, IoU: 0.6646, Acc: 0.8212, Recall: 0.8965, Precision: 0.7199, F1: 0.7985
# Epoch: 45, Train Loss: 0.4048, Valid Loss: 0.3720, IoU: 0.6640, Acc: 0.8208, Recall: 0.8958, Precision: 0.7196, F1: 0.7981
# Epoch: 46, Train Loss: 0.4398, Valid Loss: 0.3739, IoU: 0.6632, Acc: 0.8194, Recall: 0.8995, Precision: 0.7163, F1: 0.7975
# Epoch: 47, Train Loss: 0.4754, Valid Loss: 0.3771, IoU: 0.6620, Acc: 0.8174, Recall: 0.9045, Precision: 0.7117, F1: 0.7966
# Epoch: 48, Train Loss: 0.4524, Valid Loss: 0.3750, IoU: 0.6634, Acc: 0.8191, Recall: 0.9018, Precision: 0.7151, F1: 0.7976
# Epoch: 49, Train Loss: 0.4383, Valid Loss: 0.3757, IoU: 0.6630, Acc: 0.8186, Recall: 0.9025, Precision: 0.7142, F1: 0.7974
# Epoch: 50, Train Loss: 0.4134, Valid Loss: 0.3746, IoU: 0.6629, Acc: 0.8188, Recall: 0.9011, Precision: 0.7149, F1: 0.7973
# Epoch: 51, Train Loss: 0.4315, Valid Loss: 0.3734, IoU: 0.6631, Acc: 0.8194, Recall: 0.8991, Precision: 0.7165, F1: 0.7975
# Epoch: 52, Train Loss: 0.4300, Valid Loss: 0.3747, IoU: 0.6630, Acc: 0.8189, Recall: 0.9011, Precision: 0.7150, F1: 0.7973
# Epoch: 53, Train Loss: 0.4415, Valid Loss: 0.3745, IoU: 0.6635, Acc: 0.8193, Recall: 0.9010, Precision: 0.7157, F1: 0.7977
# Epoch: 54, Train Loss: 0.4407, Valid Loss: 0.3743, IoU: 0.6637, Acc: 0.8196, Recall: 0.9007, Precision: 0.7161, F1: 0.7979
# Epoch: 55, Train Loss: 0.4334, Valid Loss: 0.3737, IoU: 0.6642, Acc: 0.8201, Recall: 0.9002, Precision: 0.7170, F1: 0.7982
# Epoch: 56, Train Loss: 0.4883, Valid Loss: 0.3729, IoU: 0.6646, Acc: 0.8205, Recall: 0.8998, Precision: 0.7177, F1: 0.7985
# Epoch: 57, Train Loss: 0.4172, Valid Loss: 0.3716, IoU: 0.6650, Acc: 0.8213, Recall: 0.8974, Precision: 0.7198, F1: 0.7988
# Epoch: 58, Train Loss: 0.5167, Valid Loss: 0.3665, IoU: 0.6673, Acc: 0.8242, Recall: 0.8918, Precision: 0.7262, F1: 0.8005
# Best model saved with accuracy: 0.824249267578125
# Epoch: 59, Train Loss: 0.4986, Valid Loss: 0.3692, IoU: 0.6665, Acc: 0.8227, Recall: 0.8960, Precision: 0.7224, F1: 0.7999
# Epoch: 60, Train Loss: 0.4761, Valid Loss: 0.3721, IoU: 0.6651, Acc: 0.8210, Recall: 0.8993, Precision: 0.7187, F1: 0.7989
# Epoch: 61, Train Loss: 0.4141, Valid Loss: 0.3721, IoU: 0.6655, Acc: 0.8210, Recall: 0.9006, Precision: 0.7183, F1: 0.7992
# Epoch: 62, Train Loss: 0.4365, Valid Loss: 0.3726, IoU: 0.6653, Acc: 0.8208, Recall: 0.9008, Precision: 0.7179, F1: 0.7990
# Epoch: 63, Train Loss: 0.4104, Valid Loss: 0.3725, IoU: 0.6643, Acc: 0.8203, Recall: 0.8995, Precision: 0.7175, F1: 0.7983
# Epoch: 64, Train Loss: 0.4308, Valid Loss: 0.3736, IoU: 0.6640, Acc: 0.8199, Recall: 0.9004, Precision: 0.7167, F1: 0.7981
# Epoch: 65, Train Loss: 0.4844, Valid Loss: 0.3705, IoU: 0.6655, Acc: 0.8220, Recall: 0.8960, Precision: 0.7213, F1: 0.7992
# Epoch: 66, Train Loss: 0.4087, Valid Loss: 0.3712, IoU: 0.6642, Acc: 0.8210, Recall: 0.8953, Precision: 0.7201, F1: 0.7982
# Epoch: 67, Train Loss: 0.4330, Valid Loss: 0.3723, IoU: 0.6643, Acc: 0.8206, Recall: 0.8979, Precision: 0.7186, F1: 0.7983
# Epoch: 68, Train Loss: 0.4804, Valid Loss: 0.3719, IoU: 0.6645, Acc: 0.8205, Recall: 0.8990, Precision: 0.7181, F1: 0.7984
# Epoch: 69, Train Loss: 0.4453, Valid Loss: 0.3744, IoU: 0.6631, Acc: 0.8188, Recall: 0.9020, Precision: 0.7145, F1: 0.7974
# Epoch: 70, Train Loss: 0.4533, Valid Loss: 0.3695, IoU: 0.6653, Acc: 0.8220, Recall: 0.8952, Precision: 0.7215, F1: 0.7990
# Epoch: 71, Train Loss: 0.4554, Valid Loss: 0.3680, IoU: 0.6659, Acc: 0.8229, Recall: 0.8931, Precision: 0.7236, F1: 0.7995
# Epoch: 72, Train Loss: 0.4725, Valid Loss: 0.3693, IoU: 0.6662, Acc: 0.8227, Recall: 0.8951, Precision: 0.7226, F1: 0.7997
# Epoch: 73, Train Loss: 0.4588, Valid Loss: 0.3704, IoU: 0.6660, Acc: 0.8220, Recall: 0.8978, Precision: 0.7206, F1: 0.7995
# Epoch: 74, Train Loss: 0.4175, Valid Loss: 0.3710, IoU: 0.6656, Acc: 0.8214, Recall: 0.8991, Precision: 0.7193, F1: 0.7992
# Epoch: 75, Train Loss: 0.4689, Valid Loss: 0.3700, IoU: 0.6663, Acc: 0.8221, Recall: 0.8986, Precision: 0.7205, F1: 0.7997
# Epoch: 76, Train Loss: 0.4899, Valid Loss: 0.3687, IoU: 0.6668, Acc: 0.8227, Recall: 0.8974, Precision: 0.7218, F1: 0.8001
# Epoch: 77, Train Loss: 0.4462, Valid Loss: 0.3687, IoU: 0.6669, Acc: 0.8226, Recall: 0.8986, Precision: 0.7212, F1: 0.8002
# Epoch: 78, Train Loss: 0.4989, Valid Loss: 0.3646, IoU: 0.6690, Acc: 0.8253, Recall: 0.8929, Precision: 0.7273, F1: 0.8016
# Best model saved with accuracy: 0.8252944946289062
# Epoch: 79, Train Loss: 0.4143, Valid Loss: 0.3660, IoU: 0.6674, Acc: 0.8241, Recall: 0.8924, Precision: 0.7257, F1: 0.8005
# Epoch: 80, Train Loss: 0.4508, Valid Loss: 0.3670, IoU: 0.6676, Acc: 0.8240, Recall: 0.8942, Precision: 0.7249, F1: 0.8007
# Epoch: 81, Train Loss: 0.4538, Valid Loss: 0.3666, IoU: 0.6676, Acc: 0.8241, Recall: 0.8939, Precision: 0.7251, F1: 0.8007
# Epoch: 82, Train Loss: 0.4035, Valid Loss: 0.3682, IoU: 0.6658, Acc: 0.8225, Recall: 0.8945, Precision: 0.7225, F1: 0.7994
# Epoch: 83, Train Loss: 0.4331, Valid Loss: 0.3652, IoU: 0.6666, Acc: 0.8242, Recall: 0.8890, Precision: 0.7270, F1: 0.7999
# Epoch: 84, Train Loss: 0.4416, Valid Loss: 0.3661, IoU: 0.6665, Acc: 0.8238, Recall: 0.8905, Precision: 0.7260, F1: 0.7999
# Epoch: 85, Train Loss: 0.4477, Valid Loss: 0.3669, IoU: 0.6669, Acc: 0.8239, Recall: 0.8918, Precision: 0.7256, F1: 0.8001
# Epoch: 86, Train Loss: 0.5078, Valid Loss: 0.3681, IoU: 0.6670, Acc: 0.8233, Recall: 0.8953, Precision: 0.7235, F1: 0.8003
# Epoch: 87, Train Loss: 0.4029, Valid Loss: 0.3687, IoU: 0.6657, Acc: 0.8225, Recall: 0.8939, Precision: 0.7227, F1: 0.7993
# Epoch: 88, Train Loss: 0.4716, Valid Loss: 0.3662, IoU: 0.6668, Acc: 0.8241, Recall: 0.8904, Precision: 0.7264, F1: 0.8001
# Epoch: 89, Train Loss: 0.4569, Valid Loss: 0.3662, IoU: 0.6678, Acc: 0.8247, Recall: 0.8913, Precision: 0.7270, F1: 0.8008
# Epoch: 90, Train Loss: 0.4002, Valid Loss: 0.3702, IoU: 0.6652, Acc: 0.8218, Recall: 0.8956, Precision: 0.7211, F1: 0.7990
# Epoch: 91, Train Loss: 0.4536, Valid Loss: 0.3730, IoU: 0.6647, Acc: 0.8204, Recall: 0.9004, Precision: 0.7175, F1: 0.7986
# Epoch: 92, Train Loss: 0.4510, Valid Loss: 0.3714, IoU: 0.6652, Acc: 0.8212, Recall: 0.8987, Precision: 0.7191, F1: 0.7989
# Epoch: 93, Train Loss: 0.4016, Valid Loss: 0.3725, IoU: 0.6643, Acc: 0.8204, Recall: 0.8988, Precision: 0.7180, F1: 0.7983
# Epoch: 94, Train Loss: 0.4273, Valid Loss: 0.3734, IoU: 0.6639, Acc: 0.8200, Recall: 0.8995, Precision: 0.7171, F1: 0.7980
# Epoch: 95, Train Loss: 0.4158, Valid Loss: 0.3747, IoU: 0.6624, Acc: 0.8185, Recall: 0.9006, Precision: 0.7147, F1: 0.7969
# Epoch: 96, Train Loss: 0.4663, Valid Loss: 0.3776, IoU: 0.6610, Acc: 0.8164, Recall: 0.9052, Precision: 0.7101, F1: 0.7959
# Epoch: 97, Train Loss: 0.5201, Valid Loss: 0.3801, IoU: 0.6603, Acc: 0.8152, Recall: 0.9085, Precision: 0.7073, F1: 0.7954
# Epoch: 98, Train Loss: 0.4150, Valid Loss: 0.3784, IoU: 0.6611, Acc: 0.8166, Recall: 0.9052, Precision: 0.7103, F1: 0.7960
# Epoch: 99, Train Loss: 0.4013, Valid Loss: 0.3765, IoU: 0.6618, Acc: 0.8177, Recall: 0.9024, Precision: 0.7128, F1: 0.7965
# Epoch: 100, Train Loss: 0.4453, Valid Loss: 0.3736, IoU: 0.6640, Acc: 0.8201, Recall: 0.8993, Precision: 0.7173, F1: 0.7980

# %% [markdown]
# ## Testing of the data set and performance metrics

# %%
# Evaluate on the test set

# Denormalize function:
def denormalize(image, mean, std):
    image = image.clone().cpu().numpy()
    image = image.transpose(1, 2, 0)
    image = (image * std) + mean
    image = np.clip(image * 255, 0, 255).astype(np.uint8)  # Rescale back to [0,255]
    return image

# Function to remove bees from the image based on the predicted mask
def remove_bees(image, predicted_mask):
    # Convert the predicted mask to binary
    binary_mask = (predicted_mask > 0.5).astype(np.float32)
    inverse_mask = 1 - binary_mask
    image_without_bees = image * inverse_mask[..., None]  # Apply the inverse mask to the image
    return image_without_bees.astype(np.uint8)

# Model evaluation:
model.eval()
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# Image normalization parameters used previously
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# Initialize metrics
total_iou, total_acc, total_recall, total_precision, total_fscore = 0, 0, 0, 0, 0

with torch.no_grad():
    for images, masks in test_loader:
        images, masks = images.to(device), masks.to(device)
        outputs = model(images)

        iou, accuracy, recall, precision, f_score = get_metrics(outputs, masks)
        total_iou += iou
        total_acc += accuracy
        total_recall += recall
        total_precision += precision
        total_fscore += f_score
        
        # Visualize the images
        fig, ax = plt.subplots(1, 4, figsize=(25, 6))
        
        denorm_img = denormalize(images[0], mean, std)
        ax[0].imshow(denorm_img)
        ax[0].set_title("Original Image")
        
        image_without_bees = remove_bees(denorm_img, outputs[0][0].cpu().numpy())
        ax[1].imshow(image_without_bees)
        ax[1].set_title("Image without Bees")
        
        ax[2].imshow(masks[0][0].cpu().numpy(), cmap="gray")
        ax[2].set_title("Original Mask")
        
        ax[3].imshow(outputs[0][0].cpu().numpy(), cmap="gray")
        ax[3].set_title("Predicted Mask")
        
        plt.show()

# Average the metrics
num_test_samples = len(test_loader)
print(f"Test IoU: {total_iou/num_test_samples}")
print(f"Test Accuracy: {total_acc/num_test_samples}")
print(f"Test Recall: {total_recall/num_test_samples}")
print(f"Test Precision: {total_precision/num_test_samples}")
print(f"Test F1 Score: {total_fscore/num_test_samples}")
# Out:
# Test IoU: 0.7203906774520874
# Test Accuracy: 0.8341217041015625
# Test Recall: 0.8879200857911325
# Test Precision: 0.7917024996600872
# Test F1 Score: 0.8370110213047595

# %% [markdown]
# ## Apply the model to new images
# Input, output folders and model_path will need to be changed to personal folders/files. The model_path that you set previously should be copied to match for this code chunk. The input folder should consist of the initial images to be run through the algorithm. The output folder should be an empty folder that will store the sub-images after the bees have been removed. The final_output_folder should also be empty. This will save the final images without bees.

# %%
import os
import cv2
import numpy as np
import torch
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image

# Load the model and other variables outside of the function
model_path = "C:\\Users\\Emily\\OneDrive - Auburn University\\Capstone Work\\UNETPLUSPLUS_model.pth"
model.load_state_dict(torch.load(model_path))
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Define albumentations transformations
valid_transform = A.Compose([
    A.Resize(height=256, width=256),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# --- Functions for Image Processing ---

def preprocess_image(image_np, transform):
    # Ensure the image is in float32 format
    if image_np.dtype != np.float32:
        image_np = image_np.astype(np.float32)

    image_np = cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB)
    augmented = transform(image=image_np)
    return augmented['image']

def remove_bees_from_image(image, predicted_mask):
    # Resize the predicted mask to the size of the original image
    resized_mask = cv2.resize(predicted_mask, (image.shape[1], image.shape[0]))

    # Create a binary mask
    binary_mask = (resized_mask > 0.5).astype(np.float32)

    # Get the inverse of the mask
    inverse_mask = 1 - binary_mask

    # Remove bees from the image
    image_without_bees = image * inverse_mask.squeeze()

    return image_without_bees.astype(np.uint8)

def process_image(image_path, transform):
    image = Image.open(image_path)
    width, height = image.size
    split_width = width // 3
    split_height = height // 3

    # Create an empty array to store processed parts
    processed_parts = []

    for i in range(3):
        for j in range(3):
            left = i * split_width
            upper = j * split_height
            right = left + split_width
            lower = upper + split_height
            region = image.crop((left, upper, right, lower))
            sub_image_np = np.array(region)
            sub_image_tensor = preprocess_image(sub_image_np, transform).unsqueeze(0).to(device)

            with torch.no_grad():
                output = model(sub_image_tensor)

            predicted_mask = output[0][0].cpu().numpy()
            sub_image_without_bees = remove_bees_from_image(sub_image_np, predicted_mask)
            processed_parts.append(sub_image_without_bees)

    # Reassemble the full image from processed parts (for grayscale images)
    reassembled_image = np.zeros((height, width), dtype=np.uint8)
    for i in range(3):
        for j in range(3):
            reassembled_image[j * split_height:(j + 1) * split_height,
                              i * split_width:(i + 1) * split_width] = processed_parts[i * 3 + j]

    return Image.fromarray(reassembled_image)

def process_subfolder(subfolder_path, transform):
    image_files = sorted([os.path.join(subfolder_path, img) for img in os.listdir(subfolder_path) if img.endswith('.png')])
    reassembled_images_list = []

    # Determine the resolution of the first image in the sequence
    first_image = Image.open(image_files[0])
    first_image_width, first_image_height = first_image.size

    # Initialize the accumulated_comb array with the first image's dimensions
    accumulated_comb = np.zeros((first_image_height, first_image_width), np.float32)

    for image_file in image_files:
        reassembled_image = process_image(image_file, transform)
        image_np = np.array(reassembled_image)

        if len(image_np.shape) == 3:
            image_np = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY)

        # Ensure the image matches the dimensions of the accumulated_comb
        if image_np.shape != accumulated_comb.shape:
            image_np = cv2.resize(image_np, (first_image_width, first_image_height))

        accumulated_comb = np.maximum(accumulated_comb, image_np)
        reassembled_images_list.append(accumulated_comb.copy())

    return reassembled_images_list

def create_timelapse(input_folder, output_video, transform):
    subfolders = [os.path.join(input_folder, sub) for sub in os.listdir(input_folder) if os.path.isdir(os.path.join(input_folder, sub))]

    # Determine the resolution of the first image in the sequence
    first_image_path = os.path.join(subfolders[0], os.listdir(subfolders[0])[0])
    first_image = Image.open(first_image_path)
    first_image_width, first_image_height = first_image.size

    # Initialize the accumulated_comb array with the first image's dimensions
    accumulated_comb = np.zeros((first_image_height, first_image_width), np.float32)

    # Define the codec and create VideoWriter object with the first image's dimensions
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    out = cv2.VideoWriter(output_video, fourcc, 4, (first_image_width, first_image_height), isColor=True)

    for subfolder in subfolders:
        image_files = sorted([os.path.join(subfolder, img) for img in os.listdir(subfolder) if img.endswith('.png')])

        for image_file in image_files:
            reassembled_image = process_image(image_file, transform)
            image_np = np.array(reassembled_image)

            if len(image_np.shape) == 3:
                image_np = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY)

            # Ensure the image matches the dimensions of the accumulated_comb
            if image_np.shape != accumulated_comb.shape:
                image_np = cv2.resize(image_np, (first_image_width, first_image_height))

            accumulated_comb = np.maximum(accumulated_comb, image_np)
            frame_colored = cv2.cvtColor(np.uint8(accumulated_comb), cv2.COLOR_GRAY2BGR)
            out.write(frame_colored)

    out.release()
    print(f'The timelapse video has been saved as {output_video}')

# Call the function with the input folder and output video file
input_folder = "C:\\Users\\Emily\\OneDrive - Auburn University\\Capstone Work\\cam2_25mm-selected"
output_video = "C:\\Users\\Emily\\OneDrive - Auburn University\\Capstone Work\\mult_folders_test.mp4"
create_timelapse(input_folder, output_video, valid_transform)
# Out:
# The timelapse video has been saved as C:\Users\Emily\OneDrive - Auburn University\Capstone Work\mult_folders_test.mp4
